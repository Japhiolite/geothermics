# %% [markdown]
# First we need to import the output data from the GHLEPro simlation

# %%
# import some libraries  
import numpy as np
import pandas as p
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# enter the file name (*.)
#filename = 'data/glhewin.glo'


headers = ['Time','Q','HP-Energy','Tf','AverageExWT','AverageEWT','MinimumEWT','MaximumEWT']


data = p.read_csv('data/glhewin.glo', skiprows=110, names = headers, sep = '\s+')


#data = np.loadtxt(filename,
#delimiter='\t', #String used to separate values
#skiprows=110,
#dtype=float) #Skip the first 110 lines

data.head(10)
#print(data[2,0])
# Out:
#    Time      Q  HP-Energy     Tf  AverageExWT  AverageEWT  MinimumEWT  \
# 0     1  24.77     785.47   0.22        -0.60        1.04        1.04
# 1     2  20.71     576.34   1.35         0.66        2.04        2.04
# 2     3  11.94     337.16   4.76         4.36        5.16        5.16
# 3     4   6.80     176.37   6.91         6.69        7.14        7.14
# 4     5  -1.02       7.55  10.25        10.28       10.22       10.22
# 5     6  -5.76      43.23  12.43        12.62       12.24       12.24
# 6     7  -8.37      66.88  13.73        14.01       13.46       13.46
# 7     8  -7.18      57.01  13.43        13.67       13.20       13.20
# 8     9   0.77      18.84  10.24        10.21       10.26       10.26
# 9    10   5.79     150.90   8.06         7.87        8.25        8.25
#
#    MaximumEWT
# 0        1.04
# 1        2.04
# 2        5.16
# 3        7.14
# 4       10.22
# 5       12.24
# 6       13.46
# 7       13.20
# 8       10.26
# 9        8.25

# %%
Tf=data['Tf']

t=data['Time']

#Tmean=(T1+T2)/2


plt.plot(t,Tf,'-', linewidth=4, color='red')
#plt.plot(t,T2,'-', color='blue')
#plt.plot(t,Tmean,'-', color='green', label='mean')
#plt.legend()
plt.xlabel('Time (months)')
plt.ylabel('Temperature (°C)')

plt.grid(True)
