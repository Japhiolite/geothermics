# %%
# import some libraries  
import numpy as np
import pandas as p
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# enter the file name (*.)
#filename = 'data/glhewin.glo'


headers = ['Time','TimeStep','Head','Vx','Vy','Vz','Por','HydrCond','Perm','Temp','ThermCond','Redox']


data = p.read_csv('data/d12m-cool.002', skiprows=2, names = headers, sep = '\s+')


#data = np.loadtxt(filename,
#delimiter='\t', #String used to separate values
#skiprows=110,
#dtype=float) #Skip the first 110 lines

data.head(10)
#print(data[2,0]
# Out:
#        Time  TimeStep       Head        Vx        Vy   Vz   Por  HydrCond  \
# 0  0.608333  0.608333  25.054925  3.021767  0.160002  0.0  0.35  0.000225
# 1  1.216667  0.608333  25.054940  3.019697  0.159893  0.0  0.35  0.000225
# 2  1.825000  0.608333  25.054940  3.019666  0.159881  0.0  0.35  0.000225
# 3  2.433333  0.608333  25.054940  3.019518  0.159877  0.0  0.35  0.000225
# 4  3.041667  0.608333  25.054939  3.019636  0.159920  0.0  0.35  0.000225
# 5  3.650000  0.608333  25.054939  3.019603  0.159914  0.0  0.35  0.000225
# 6  4.258333  0.608333  25.054939  3.019599  0.159913  0.0  0.35  0.000225
# 7  4.866667  0.608333  25.054939  3.019628  0.159915  0.0  0.35  0.000225
# 8  5.475000  0.608333  25.054939  3.019658  0.159919  0.0  0.35  0.000225
# 9  6.083333  0.608333  25.054939  3.019655  0.159918  0.0  0.35  0.000225
#
#            Perm       Temp  ThermCond  Redox
# 0  3.000000e-11  10.000001        2.7    0.0
# 1  3.000000e-11  10.000000        2.7    0.0
# ...

# %%
Temp=data['Temp']

t=data['Time']

#Tmean=(T1+T2)/2


plt.plot(t,Temp,'-', linewidth=4, color='red')
#plt.plot(t,T2,'-', color='blue')
#plt.plot(t,Tmean,'-', color='green', label='mean')
#plt.legend()
plt.xlabel('Time (days)')
plt.ylabel('Temperature (°C)')

plt.grid(True)
